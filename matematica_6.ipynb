# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Задание.
# При фиксированном seed=42 поразбирайтесь и поэкспериментируйте с параметрами алгоритма дифференциальной эволюции: strategy, popsize, tol, mutation, recombination и updating.

# %% [markdown]
# # Параметры по умолчанию!

# %%
def ackley(x):
    arg1 = -0.2 * np.sqrt(0.5 * (x[0] ** 2 + x[1] ** 2))
    arg2 = 0.5 * (np.cos(2. * np.pi * x[0]) + np.cos(2. * np.pi * x[1]))
    return -20. * np.exp(arg1) - np.exp(arg2) + 20. + np.e

bounds = [(-10, 10), (-10, 10)]

result = differential_evolution(ackley, bounds, seed=42)
result
# Out:
#      fun: 4.440892098500626e-16
#  message: 'Optimization terminated successfully.'
#     nfev: 2793
#      nit: 90
#  success: True
#        x: array([0., 0.])

# %% [markdown]
# # Эксперементальные параметры

# %%
def ackley(x):
    arg1 = -0.2 * np.sqrt(0.5 * (x[0] ** 2 + x[1] ** 2))
    arg2 = 0.5 * (np.cos(2. * np.pi * x[0]) + np.cos(2. * np.pi * x[1]))
    return -20. * np.exp(arg1) - np.exp(arg2) + 20. + np.e

bounds = [(-10, 10), (-10, 10)]

result = differential_evolution(ackley, bounds, strategy = 'best1bin', popsize = 15 , tol=0.01, mutation =(0.5, 1),  recombination=0.7, seed=42, updating='immediate')
result
# Out:
#      fun: 4.440892098500626e-16
#  message: 'Optimization terminated successfully.'
#     nfev: 2793
#      nit: 90
#  success: True
#        x: array([0., 0.])

# %% [markdown]
# # Параметры экпериментов занес в отдельный файл

# %%
df = pd.read_excel('C:\\Users\\kuznecov.ap\\Desktop\\Математика для Data Science\\6_Теория оптимизации\\seed.xlsx')
df.head(36)
# Out:
#     number             strategy  popsize    tol  mutation_1  mutation_2  \
# 0        1           'best1bin'       15  0.010         0.5         1.0
# 1        2           'best1exp'       15  0.010         0.5         1.0
# 2        3           'rand1exp'       15  0.010         0.5         1.0
# 3        4     'randtobest1exp'       15  0.010         0.5         1.0
# 4        5  'currenttobest1exp'       15  0.010         0.5         1.0
# 5        6           'best2exp'       15  0.010         0.5         1.0
# 6        7           'rand2exp'       15  0.010         0.5         1.0
# 7        8     'randtobest1bin'       15  0.010         0.5         1.0
# 8        9  'currenttobest1bin'       15  0.010         0.5         1.0
# 9       10           'best2bin'       15  0.010         0.5         1.0
# 10      11           'rand2bin'       15  0.010         0.5         1.0
# 11      12           'rand1bin'       15  0.010         0.5         1.0
# ...

# %% [markdown]
# # Постройте графики количества итераций оптимизации функции ackley от значения параметра.

# %%
#увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 13,6
ax = df.plot(title='Значения параметра "nit"', 
                             xlabel='Номер эксперимента', 
                             ylabel='Значение, ед.')

# %%
df[['nit']].plot(title='Значения параметра "nit"', 
                             xlabel='Номер эксперимента', 
                             ylabel='Значение, ед.');
